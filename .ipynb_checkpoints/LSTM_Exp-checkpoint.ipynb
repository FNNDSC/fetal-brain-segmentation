# %%
from datahandler import DataHandler
from models.unet import *
from generator import *
from params import *
from callbacks import getCallbacks

from tqdm import tqdm
import os
import skimage.io as io

from keras.models import *
from keras import backend as K

# %matplotlib inline
import matplotlib.pyplot as plt

import argparse
import sys
# Out:
# Using TensorFlow backend.

# %%
#set common variables
epochs = 25
batch_size = 32
verbose = 1


resetSeed()

# %%
#Get data and generators
dh = DataHandler()
tr_images, tr_masks, te_images, te_masks = dh.getData()
# Out:
# Training data: 100%|██████████████████████████| 172/172 [02:40<00:00,  1.16it/s]
# Validation data: 100%|██████████████████████████| 43/43 [00:43<00:00,  1.01it/s]

# %%
unet_model = getUnet()
unet_graph = tf.get_default_graph()

with unet_graph.as_default():
    unet_model.load_weights('logs/unet/kfold_unet/kfold_unet_dice_DA_K2/kfold_unet_dice_DA_K2_weights.h5')
# Out:
# /home/alejandrovaldes/projects/fetal-brain-segmentation/models/unet.py:68: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("co...)`
#   model = Model(input = inputs, output = conv10)

# %%
import random

def generator(images, masks, batch_size):
    i = 0
    while True:
        batch_features = []
        batch_labels = []
        
        c = batch_size * i 
        
        if c == len(images):
            i = 0
            c = 0

        for j in range(c, c + batch_size):
            if j == 0:
                res1 =  np.expand_dims(np.zeros(images[j].shape), axis=0)
            else:
                img1 = np.expand_dims(images[j-1], axis=0)
                with unet_graph.as_default():
                    res1 = unet_model.predict(img1)

            img2 = np.expand_dims(images[j], axis=0) 
            with unet_graph.as_default():
                res2 = unet_model.predict(img2)

            if j == images.shape[0]-1:
                res3 = np.expand_dims(np.zeros(images[j].shape), axis=0)
            else:
                img3 = np.expand_dims(images[j+1], axis=0)
                with unet_graph.as_default():
                    res3 = unet_model.predict(img3)

            res = np.concatenate((res1,res2,res3), axis=0)
            res[res>=0.7] = 1
            res[res<0.7] = 0
            
            mask = masks[j]
            mask[mask == 255] = 1
            
            batch_features.append(res)
            batch_labels.append(mask)
        i += 1

        yield np.array(batch_features), np.array(batch_labels)

# %%
train_generator = generator(tr_images[:60], tr_masks[:60], 4)
val_generator = generator(te_images[:20], te_masks[:20], 4)

# %%
from keras.models import Model
from keras.layers import Input, MaxPooling2D, Dropout, Conv2D, Conv2DTranspose, TimeDistributed, Bidirectional, ConvLSTM2D
from keras import backend as K
import tensorflow as tf
from keras.optimizers import RMSprop, Adam, SGD
from keras.losses import binary_crossentropy
from losses import *
import math


lstm_graph = tf.get_default_graph()

with lstm_graph.as_default():

    inputs = Input((3, 256, 256, 1))

    bclstm = Bidirectional(ConvLSTM2D(32, 3, return_sequences = True, padding='same', activation = 'relu'))(inputs)
    bclstm = Bidirectional(ConvLSTM2D(32, 3, return_sequences = True, padding='same', activation = 'relu'))(bclstm)

    pool = TimeDistributed(MaxPooling2D(pool_size=2))(bclstm)

    bclstm = Bidirectional(ConvLSTM2D(64, 3, return_sequences = True, padding='same', activation = 'relu'))(pool)
    bclstm = Bidirectional(ConvLSTM2D(64, 3, return_sequences = True, padding='same', activation = 'relu'))(bclstm)
    bclstm = Bidirectional(ConvLSTM2D(64, 3, padding='same', activation = 'relu'))(bclstm)

    up = Conv2DTranspose(64,3, strides=2, padding='same', activation = 'relu')(bclstm)
    conv = Conv2D(64, 3, activation = 'relu', padding='same')(up)

    outputs = Conv2D(1, (1,1), activation = 'sigmoid')(conv)

    model = Model(input = inputs, output = outputs)
    
    model.compile(optimizer = Adam(lr = 1e-4),
            loss = binary_crossentropy, metrics = [dice_coef])
    
    model.fit_generator(train_generator, validation_data=val_generator, 
                        validation_steps=math.ceil(len(te_images[:20])/4),
                        steps_per_epoch=math.ceil(len(tr_images[:60])/4), epochs=10)
# Out:
# /home/alejandrovaldes/.virtualenvs/fetal-brain-segmentation-9O2pP5m0/lib/python3.6/site-packages/ipykernel_launcher.py:31: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("co...)`
# Epoch 1/10
# 15/15 [==============================] - 29s 2s/step - loss: 0.6908 - dice_coef: 0.0507 - val_loss: 0.6875 - val_dice_coef: 0.0679
# Epoch 2/10
# 15/15 [==============================] - 22s 1s/step - loss: 0.6831 - dice_coef: 0.0507 - val_loss: 0.6773 - val_dice_coef: 0.0679
# Epoch 3/10
# 15/15 [==============================] - 22s 1s/step - loss: 0.6673 - dice_coef: 0.0506 - val_loss: 0.6518 - val_dice_coef: 0.0679
# Epoch 4/10
# 15/15 [==============================] - 22s 1s/step - loss: 0.6121 - dice_coef: 0.0517 - val_loss: 0.5358 - val_dice_coef: 0.0730
# Epoch 5/10
# 15/15 [==============================] - 22s 1s/step - loss: 0.3425 - dice_coef: 0.0867 - val_loss: 0.0938 - val_dice_coef: 0.2397
# Epoch 6/10
# 15/15 [==============================] - 22s 1s/step - loss: 0.0460 - dice_coef: 0.3874 - val_loss: 0.0358 - val_dice_coef: 0.4695
# Epoch 7/10
# 15/15 [==============================] - 22s 1s/step - loss: 0.0276 - dice_coef: 0.4943 - val_loss: 0.0237 - val_dice_coef: 0.5735
# Epoch 8/10
# 15/15 [==============================] - 22s 1s/step - loss: 0.0160 - dice_coef: 0.6966 - val_loss: 0.0128 - val_dice_coef: 0.7212
# Epoch 9/10
# 15/15 [==============================] - 22s 1s/step - loss: 0.0119 - dice_coef: 0.7441 - val_loss: 0.0104 - val_dice_coef: 0.7205
# Epoch 10/10
# 15/15 [==============================] - 22s 1s/step - loss: 0.0121 - dice_coef: 0.7329 - val_loss: 0.0109 - val_dice_coef: 0.7188

# %%
j = 812
with unet_graph.as_default():
    img1 = np.expand_dims(tr_images[j-1], axis=0)
    res1 = unet_model.predict(img1)
    res1[res1>=0.7] = 1
    res1[res1<0.7] = 0
    
    img2 = np.expand_dims(tr_images[j], axis=0) 
    res2 = unet_model.predict(img2)
    res2[res2>=0.7] = 1
    res2[res2<0.7] = 0
    
    img3 = np.expand_dims(tr_images[j+1], axis=0)
    res3 = unet_model.predict(img3)
    res3[res3>=0.7] = 1
    res3[res3<0.7] = 0
    
plt.gray()

# %%
plt.imshow(np.squeeze(tr_images[j-1] + res1 * 255))

# %%
plt.imshow(np.squeeze(tr_images[j] + res2 * 255))

# %%
plt.imshow(np.squeeze(tr_images[j+1] + res3 * 255))

# %%
plt.imshow(np.squeeze(tr_images[j] + tr_masks[j]))

# %%
res = np.array([np.concatenate((res1,res2,res3), axis=0)])
res[res >= 0.7] = 1
res[res < 0.7] = 0

print(res.shape)

with lstm_graph.as_default():
    r = model.predict(res)
    print(r.shape)
# Out:
# (1, 3, 256, 256, 1)
# (1, 256, 256, 1)

# %%
r[r<0.7] = 0
r[r>0.7] = 1
plt.imshow(np.squeeze(tr_images[j] + res2[0] * 255 ))

# %%
plt.imshow(np.squeeze(tr_images[j] + r[0] * 255 ))

# %%
plt.imshow(np.squeeze(tr_images[j] + tr_masks[j]))

# %%
from sklearn.metrics import f1_score
mask = tr_masks[j]
mask[mask==255] = 1

res2[res2>=0.7] = 1
res2[res2<0.7] = 0

print(np.unique(mask))
print(np.unique(r[0]))
print(np.unique(res2[0]))
print(mask.shape)
print(r[0].shape)
print(res2[0].shape)

print(f1_score(r[0].flatten(), mask.flatten()))
print(f1_score(res2[0].flatten(), mask.flatten()))
# Out:
# [0 1]
# [0. 1.]
# [0. 1.]
# (256, 256, 1)
# (256, 256, 1)
# (256, 256, 1)
# 0.7282835302293259
# 0.8217054263565892
